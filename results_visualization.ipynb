# %%
from visualize_molecules import visualize_molecules
from plot_results import plot_temperatures, plot_probabilities, plot_new_Generated_Mol, plot_plot_new_Generated_Mol_Criteria

# %% [markdown]
# ## Visualizing new molecules generated

# %%
limit = 3

visualize_molecules(n_molecules=limit)
# Out:
# <div style="margin-bottom: 20px; text-align: center;"><p style="font-size: 18px; font-weight: bold;">Total number of molecules generated: 8</p><p style="font-size: 16px; font-weight: bold;">Displaying first 3 molecules</p></div><table style="border-collapse: collapse; margin: 0 auto;"><tr><th style="padding: 10px; border: 1px solid black; background-color: #2196F3; color: white; text-align: center;">Structure</th><th style="padding: 10px; border: 1px solid black; background-color: #2196F3; color: white; text-align: center;">SMILES</th></tr><tr><td style="padding: 10px; border: 1px solid black; text-align: center;"><img src="data:image/png;base64,..."></td><td style="padding: 10px; border: 1px solid black; text-align: center;">COC1CN(C(=O)c2c(C3=NC(=O)CCS3)sc3c2CCCC3)C1</td></tr><tr><td style="padding: 10px; border: 1px solid black; text-align: center;"><img src="data:image/png;base64,..."></td><td style="padding: 10px; border: 1px solid black; text-align: center;">O=C(CN1CCCCC1)NCc1s
# ...

# %% [markdown]
# ## Visualizing the temperature decay over the iterations

# %%
plot_temperatures()

# %% [markdown]
# ## Visualization of average probability decay  over the iterations

# %%
plot_probabilities()

# %% [markdown]
# ## Visualization of the amount of newly generated molecules throughout the iterations

# %%
plot_new_Generated_Mol()
# Out:
# Total: 4937

# %% [markdown]
# ## Evolution of the number of distinct new molecules meeting the selection criteria over successive iterations.

# %%
plot_plot_new_Generated_Mol_Criteria()
